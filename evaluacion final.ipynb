# %% [markdown]
# EJERCICIO
#
# La tiendaOnline será una tienda de ropa.

# %%
class TiendaOnline: 
    def __init__ (self):
        self.inventario = []
        self.ventas_totales = 0.0

    def agregar_producto(self, nombre, precio, cantidad):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                producto["cantidad"] = producto["cantidad"] + cantidad
                return 

        nuevo_producto = {"nombre": nombre, "precio": precio, "cantidad": cantidad}
        self.inventario.append(nuevo_producto)
    
    def ver_inventario(self):
        for producto in self.inventario:
            print("Nombre:" , producto["nombre"] , ",""Precio:", producto["precio"], 
            ",","Cantidad:", producto["cantidad"])

    def buscar_producto(self, nombre):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                print( "Nombre:", producto["nombre"], ",", "Precio:", producto["precio"], ",",
                 "Cantidad:", producto["cantidad"] )
                return
        
        print("Producto no encontrado")

    def actualizar_stock(self, nombre, cantidad):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                producto["cantidad"] = producto["cantidad"] + cantidad
                return
        
        print("Producto no encontrado")

    def eliminar_producto(self, nombre):
        for producto in self.inventario:
            if producto["nombre"] == nombre:
                self.inventario.remove(producto)
                return
        
        print("Producto no encontrado")

    def calcular_valor_inventario(self):
        valor_total = 0

        for producto in self.inventario:
            precio = producto["precio"]
            cantidad = producto["cantidad"]
            valor_producto = precio * cantidad
            valor_total = valor_total + valor_producto

        return valor_total

# %%
#La primera prueba será crear la tienda , con class he creado la plantilla solo
tienda = TiendaOnline() #Cuidado con las mayusculas y minusculas
print(tienda.inventario) #Lista con diccionarios dentro
print(tienda.ventas_totales) #Esto será un número y me dará 0 porque no hay productos de momento
#De momento la lista se va a ver asi porque aún no hemos añadido productos con el primer método 
print("-------------------------------------")

tienda = TiendaOnline()
#Estructura general --> objeto.metodo(parametros)
#el objeto es tienda y en este caso el metodo es agregar_producto
#el punto significa esto pertenece a...
tienda.agregar_producto("camisa" , 20, 40) #añado una camisa con precio y cantidad
tienda.agregar_producto("pantalon" , 30, 30) #añado un pantalon con precio y cantidad
tienda.ver_inventario() #le digo que me lo muestre con los agregados
print("---------------------------------------")

tienda.buscar_producto("camisa") #busco este producto que si está
tienda.buscar_producto("Brocoli") #busco este producto que no existe
print("---------------------------------------")

tienda.actualizar_stock("camisa", 10) #Actualizo el stock sumando a la cantidad en 10 uds
tienda.buscar_producto("camisa")

tienda.actualizar_stock("camisa", -5) #Actualizo el stock restando a la cantidad en 5 uds
tienda.buscar_producto("camisa") #compruebo que la cantidad ha sido actualizada

tienda.actualizar_stock("brocoli", 5) #Prueba para ver que no puede actualizar algo que no existe en mi inventario
print("---------------------------------------")

tienda.ver_inventario() #Ver inventario antes de eliminar
print("---------------------------------------")

tienda.eliminar_producto("pantalon") #Elimino un producto que si existe
tienda.ver_inventario() #compruebo que se ha eliminado

print("---------------------------------------")
tienda.eliminar_producto("zapatos") #Intento eliminar un producto que no existe

print("---------------------------------------")


tienda.agregar_producto("camisa", 20, 25) #como camisa existe le añado stock  
tienda.agregar_producto("pantalon", 30, 30) #le añado otra vez el pantalon porque lo habia borrado antes 
tienda.ver_inventario() #que me enseñe como quede ahora

total = tienda.calcular_valor_inventario() #que calcule (20x70)+(30x30)


print(total)
# Out:
# []
# 0.0
# -------------------------------------
# Nombre: camisa ,Precio: 20 , Cantidad: 40
# Nombre: pantalon ,Precio: 30 , Cantidad: 30
# ---------------------------------------
# Nombre: camisa , Precio: 20 , Cantidad: 40
# Producto no encontrado
# ---------------------------------------
# Nombre: camisa , Precio: 20 , Cantidad: 50
# Nombre: camisa , Precio: 20 , Cantidad: 45
# Producto no encontrado
# ---------------------------------------
# Nombre: camisa ,Precio: 20 , Cantidad: 45
# Nombre: pantalon ,Precio: 30 , Cantidad: 30
# ---------------------------------------
# Nombre: camisa ,Precio: 20 , Cantidad: 45
# ---------------------------------------
# Producto no encontrado
# ---------------------------------------
# Nombre: camisa ,Precio: 20 , Cantidad: 70
# Nombre: pantalon ,Precio: 30 , Cantidad: 30
# 2300
